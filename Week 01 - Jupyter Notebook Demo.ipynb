# %% [markdown]
# ## Jupyter Notebooks allow you to:
#     * Run Python Code
#     * Run shell commands
#     * Use Markdown / Latex for documentation
#     * Generate static and interactive visualizations
#     * Add external multimedia artifacts to your code
#     * Leverage "magic functions"

# %% [markdown]
# ##  <span style="color:blue">Running Python Code</span>

# %% [markdown]
# #### Note that above we used HTML `<span>` tags to color our markdown

# %%
nums = [1,2,3,4,5,6,7]

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
for num in nums:
    print(num**3)
# Out:
# 1
# 8
# 27
# 64
# 125
# 216
# 343

# %% [markdown]
# ##  <span style="color:blue">Running shell commands</span>

# %%
pwd
# Out:
# 'C:\\Users\\anfib\\Dropbox\\NEU\\cs6220\\cs6220spring2022\\Course Repo'

# %% [markdown]
# ##  <span style="color:blue">Doing simple math</span>

# %%
10 + 15 - 9
# Out:
# 16

# %% [markdown]
# ##  <span style="color:blue">Documenting your code with Markdown / LateX</span>

# %% [markdown]
# Here is some raw text

# %% [raw]
# And below is a nice equation written in LateX

# %% [markdown]
# ## $$d = \sqrt{\sum{x-y^2}} \times \int{\frac{z}{w_2+w_3}}$$

# %% [markdown]
# ##  <span style="color:blue">We can display jpeg, png, gif</span>

# %%
from IPython.core.display import Image 
Image(width=600,url='http://www.catgifpage.com/gifs/310.gif')
# Out:
# <img src="http://www.catgifpage.com/gifs/310.gif" width="600"/>

# %% [markdown]
# Even YouTube videos can be embedded to notebook documents:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('K7dcSr04G8s', start=34, autoplay=1)

# %% [markdown]
# ##  <span style="color:blue">Adding plots to your code in-line</span>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.linspace(0,5)
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
x = np.linspace(0,5)
plt.plot(x,sin(x), color='red');

# %% [markdown]
# ##  <span style="color:blue">Magic functions can be quite handy</span>

# %% [markdown]
# #### Here is a list of all magic functions available

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# #### `time` can be used to measure runtime of Python snippets

# %%
# %time x = range(100)
# Out:
# Wall time: 0 ns

# %% [markdown]
# #### `timeit` takes it a step further and automatically runs your code multiple times while tracking runtime

# %%
# %%timeit x = range(100)
    max(x)
# Out:
# 1.4 µs ± 10.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# #### `who` lists all variables currently instantiated

# %%
# %who
# Out:
# Image	 YouTubeVideo	 num	 nums	 x

# %% [markdown]
# #### `env` lists your enviroment variables for your reference`

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'AMDRMPATH': 'C:\\Program Files\\AMD\\RyzenMaster\\',
#  'AMDRMSDKPATH': 'C:\\Program Files\\AMD\\RyzenMasterSDK\\',
#  'APPDATA': 'C:\\Users\\anfib\\AppData\\Roaming',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'DESKTOP-G9FMBKV',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': 'C:\\Users\\anfib\\anaconda3\\Scripts\\conda.exe',
#  'CONDA_PREFIX': 'C:\\Users\\anfib\\anaconda3',
#  'CONDA_PROMPT_MODIFIER': '(base) ',
#  'CONDA_PYTHON_EXE': 'C:\\Users\\anfib\\anaconda3\\python.exe',
#  'CONDA_SHLVL': '1',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#  'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\anfib',
#  'INTEL_DEV_REDIST': 'C:\\Program Files (x86)\\Common Files\\Intel\\Shared Libraries\\',
#  'LOCALAPPDATA': 'C:\\Users\\anfib\\AppData\\Local',
#  'LOGONSERVER': '\\\\DESKTOP-G9FMBKV',
#  'NUMBER_OF_PROCESSORS': '16',
#  'ONEDRIVE': 'C:\\Users\\anfib\\OneDrive',
#  'ONEDRIVECONSUMER': 'C:\\Users\\anfib\\OneDrive',
#  'OS': 'Windows_NT',
#  'PATH': 'C:\\Users\\anfib\\anaconda3;C:\\Users\\anfib\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\anfib\\anaconda3\\Library\\usr\\bin;C:\\Users\\anfib\\anaconda3\\Library\\bin;C:\\Users\\anfib\\anaconda3\\Scripts;C:\\Users\\anfib\\anaconda3\\bin;C:\\Users\\anfib\\anaconda3\\condabin;C:\\Program Files (x86)\\Common Files\\Intel\\Shared Libraries\\redist\\intel64_win\\compiler;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\dotnet;C:\\Program Files\\PuTTY;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\ProgramData\\DockerDesktop\\version-bin;C:\\Users\\anfib\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\anfib\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\anfib\\AppData\\Local\\Microsoft\\WindowsApps;.;C:\\Users\\anfib\\anaconda3\\lib\\site-packages\\numpy\\.libs',
#  'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#  'PROCESSOR_ARCHITECTURE': 'AMD64',
#  'PROCESSOR_IDENTIFIER': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#  'PROCESSOR_LEVEL': '23',
#  'PROCESSOR_REVISION': '7100',
#  'PROGRAMDATA': 'C:\\ProgramData',
#  'PROGRAMFILES': 'C:\\Program Files',
#  'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#  'PROGRAMW6432': 'C:\\Program Files',
#  'PROMPT': '(base) $P$G',
#  'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules',
#  'PUBLIC': 'C:\\Users\\Public',
#  'SESSIONNAME': 'Console',
#  'SYSTEMDRIVE': 'C:',
#  'SYSTEMROOT': 'C:\\WINDOWS',
#  'TEMP': 'C:\\Users\\anfib\\AppData\\Local\\Temp',
#  'TMP': 'C:\\Users\\anfib\\AppData\\Local\\Temp',
#  'USERDOMAIN': 'DESKTOP-G9FMBKV',
#  'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-G9FMBKV',
#  'USERNAME': 'everaldo',
#  'USERPROFILE': 'C:\\Users\\anfib',
#  'WINDIR': 'C:\\WINDOWS',
#  'KERNEL_LAUNCH_TIMEOUT': '40',
#  'JPY_INTERRUPT_EVENT': '1496',
#  'IPY_INTERRUPT_EVENT': '1496',
#  'JPY_PARENT_PID': '1072',
#  'TERM': 'xterm-color',
#  'CLICOLOR': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'}

# %% [markdown]
# A full list of of magic functions can be found here: https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# ##  <span style="color:blue">Interactive plots</span>

# %%
import pandas as pd
import chart_studio.plotly as py
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x1 = np.random.randn(200) - 1 
x2 = np.random.randn(200)
x3 = np.random.randn(200) + 1 

hist_data = [x1, x2, x3]

group_labels = ['Group 1', 'Group 2', 'Group 3']
colors = ['#333F44', '#37AA9C', '#94F3E4']

# %%
# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, show_hist=False, colors=colors)

# Add title
fig['layout'].update(title='Curve and Rug Plot')
# Out:
# Layout({
#     'barmode': 'overlay',
#     'hovermode': 'closest',
#     'legend': {'traceorder': 'reversed'},
#     'template': '...',
#     'title': {'text': 'Curve and Rug Plot'},
#     'xaxis': {'anchor': 'y2', 'domain': [0.0, 1.0], 'zeroline': False},
#     'yaxis': {'anchor': 'free', 'domain': [0.35, 1], 'position': 0.0},
#     'yaxis2': {'anchor': 'x', 'domain': [0, 0.25], 'dtick': 1, 'showticklabels': False}
# })

# %%
iplot(fig)
# Out:
# <div>
#
#
#             <div id="c8624857-df2b-489f-9b65-955b22acf779" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c8624857-df2b-489f-9b65-955b22acf779")) {
#                     Plotly.newPlot(
#                         'c8624857-df2b-489f-9b65-955b22acf779',
#                         [{"legendgroup": "Group 1", "marker": {"color": "#333F44"}, "mode": "lines", "name": "Group 1", "showlegend": true, "type": "scatter", "x": [-3.5902701766787595, -3.5798250445068382, -3.5693799123349166, -3.5589347801629954, -3.548489647991074, -3.5380445158191525, -3.5275993836472312, -3.51715425147531, -3.5067091193033884, -3.496263987131467, -3.485818854959546, -3.4753737227876242, -3.464928590615703, -3.454483458443782, -3.44403832627186, -3.433593194099939, -3.4231480619280177, -3.4127029297560965, -3.402257797584175, -3.3918126654122536, -3.3813675332403323, -3.3709224010684107, -3.3604772688964895, -3.3500321367245682, -3.3395870045526466, -3.3291418723807253, -3.318696740208804, -3.3082516080368825, -3.2978064758649612, -3.28736134369304, -3.2769162115211183, -3.266471079349197, -3.256025947177276, -3.2455808150053542, -3.235135682833433, -3.224690550661512, -3.2142454184895